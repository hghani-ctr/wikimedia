# %%
import wmfdata as wmf
import pandas as pd

# %%
query = wmf.spark.run("""
WITH registered_users AS (
    SELECT
        mwh.event_user_text AS user_name,
        MIN(mwh.event_user_registration_timestamp) AS registration_date
    FROM wmf.mediawiki_history mwh
    INNER JOIN canonical_data.wikis wikis ON mwh.wiki_db = wikis.database_code
    WHERE
        size(mwh.event_user_is_bot_by) = 0
        AND size(mwh.event_user_is_bot_by_historical) = 0
        AND mwh.snapshot = '2024-01'
        AND wikis.database_group IN (
            "commons", "incubator", "foundation", "mediawiki", "meta", "sources",
            "species", "wikibooks", "wikidata", "wikifunctions", "wikinews",
            "wikipedia", "wikiquote", "wikisource", "wikiversity", "wikivoyage",
            "wiktionary"
        )
    GROUP BY mwh.event_user_text
    HAVING registration_date BETWEEN '2024-01-01' AND '2024-31-01'
),
user_content_edits AS (
    SELECT
        mwh.event_user_text AS user_name,
        SUM(CASE WHEN COALESCE(mwh.page_namespace_is_content, FALSE) THEN 1 ELSE 0 END) AS content_edits
    FROM wmf.mediawiki_history mwh
    INNER JOIN canonical_data.wikis wikis ON mwh.wiki_db = wikis.database_code
    INNER JOIN registered_users ru ON mwh.event_user_text = ru.user_name
    WHERE
        mwh.event_entity = 'revision'
        AND mwh.event_type = 'create'
        AND mwh.snapshot = '2024-01'
        AND mwh.event_timestamp BETWEEN '2024-01-01' AND '2024-31-01'
        AND wikis.database_group IN (
            "commons", "incubator", "foundation", "mediawiki", "meta", "sources",
            "species", "wikibooks", "wikidata", "wikifunctions", "wikinews",
            "wikipedia", "wikiquote", "wikisource", "wikiversity", "wikivoyage",
            "wiktionary"
        )
    GROUP BY mwh.event_user_text
    HAVING content_edits >= 5
)
SELECT
    ru.user_name,
    ru.registration_date,
    uce.content_edits
FROM user_content_edits uce
INNER JOIN registered_users ru ON uce.user_name = ru.user_name;


""")

# %%
query.to_csv('df.csv', index = False)

# %%
fixed = wmf.spark.run("""WITH earliest_registration AS (
    SELECT
        user_name,
        MIN(user_registration) AS earliest_registration_date
    FROM wmf_product.editor_month
    WHERE
        user_id != 0
    GROUP BY user_name
),
global_edits AS (
    SELECT
        em.month,
        em.user_name,
        SUM(em.content_edits) AS content_edits,
        MAX(em.bot_by_group) AS bot_by_group,
        CAST(TRUNC(er.earliest_registration_date, 'MONTH') AS DATE) AS registration_month
    FROM wmf_product.editor_month em
    INNER JOIN earliest_registration er ON em.user_name = er.user_name
    WHERE
        em.MONTH = '2024-01-01'
        AND em.user_id != 0
        AND em.user_name NOT REGEXP 'bot\\b'
        and em.user_name = 'Adexgifted'
    GROUP BY em.month, em.user_name, er.earliest_registration_date
)
SELECT
 * 
FROM global_edits
--WHERE content_edits >= 5
--    AND NOT bot_by_group
--GROUP BY month;""")

fixed
# Out:
#        month   user_name  content_edits  bot_by_group registration_month
# 0 2024-01-01  Adexgifted              6         False         2024-01-01

# %%
df = pd.read_csv("df.csv")

# %%
#fixed['registration'] = pd.to_datetime(fixed['registration_month'])

filtered_rows = fixed[fixed['registration_month'] == pd.Timestamp('2024-01-01')]
# Out:
# /home/hghani/.conda/envs/2023-08-15T23.19.45_hghani/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)

# %%
filtered_rows=filtered_rows[filtered_rows['content_edits'] > 4]

# %%
missing = set(filtered_rows.user_name) - set(df.user_name)

# %%
missing
# Out:
# {'123qweasd-tk',
#  'AFröhlich',
#  'Abu1ameen',
#  'AcademiaGSouth',
#  'Adam40x',
#  'Adexgifted',
#  'Ahmed.khalil12410',
#  'Aleksej Tilman',
#  'AlexanderBot04',
#  'Alexia Eng',
#  'Alexisyoga',
#  'Almitu',
#  'Alpha beta boy',
#  'Amanteanodoc',
#  'Amir ked',
#  'AmirAbbasFattahi',
#  'Ankulbelhi',
#  'Aqqbot',
#  'Arifrahmanbot',
#  'Asifupm23',
#  'Asmakabiri',
#  'Astronomical Editor',
#  'Atelier oï 2520',
#  'Atomicfart2009',
#  'Atomicrainn',
#  'Babylas48',
#  'Balinagency',
#  'Beatricelimonti',
#  'Bercanda Saja',
#  'Bhotels',
#  'Binibining Pilipinas Bot',
#  'Book Elizabeth',
#  'Bookybo',
#  'Bot Baku',
#  'Bot plsss man',
#  'Bot1984',
#  'Botty the BoBo 2',
#  'Bulalo bot',
#  'Caaassio',
#  "Carmine Monaco d'Ambrosia",
#  'Cchjsvjebfjbv',
#  'Chamilofficial',
#  'Clear bot of Wik',
#  'Cocofai',
#  'CorrectBioBot',
#  'DAKSHABEN BHALIYA',
#  'DALILUA',
#  'DaSilvaSeth',
#  'Daledarlington',
#  'Danielandreasbeck',
#  'Dariia Kostiuk',
#  'Dean Gigler',
#  'Deeafrikanstori',
#  'Dickman78',
#  'Didebaneresaneh',
#  'Dileepkumarpi',
#  'Dillweedbagadae',
#  'Dr.stop80',
#  'DrChabuk',
#  'Dvircohen222',
#  'E931u04g4ru,4',
#  'EBons',
#  'Editsssss phhhhhh bot',
#  'Elia Frankin',
#  'Ericnarro',
#  'Escarda',
#  'Evbot99',
#  'Ewwbot',
#  'FFFbot',
#  'Fatemghrbn',
#  'Fathia Yusuf',
#  'Firat Ulus',
#  'Flagswodum',
#  'Fofadja',
#  'Fractalize',
#  'Fusionfingers',
#  'Gaia1st',
#  'Gorol1123',
#  'Habib5858',
#  'Heflin LD',
#  'HexM',
#  'HyperDiary',
#  'IXAWAI',
#  'Indicebot',
#  'InformasiBot',
#  'Inull Deutschland',
#  'Italianoa 9000',
#  'ItsGunday',
#  'Jabbot1794',
#  'Jaboh97',
#  'JanPistelak',
#  'Jonafa',
#  'Justine Urlch',
#  'Kapitan Marvel',
#  'Karlheinz Deppe-Wiesinger',
#  'Kipokip',
#  'Kissmhie1',
#  'KreativKvikksølv',
#  'LWJ15',
#  'LabarreX',
#  'Lg1236',
#  'Lola978',
#  'LuciusFlamma',
#  'Ludoholidays',
#  'Lukeysu',
#  'MAEW57',
#  'Mahmoodeb',
#  'Malgus889',
#  'Marcika193',
#  'Mbjpxncp7k',
#  'Minnerbot XD',
#  'Miss Universe Editor.Bot',
#  'Mliz2000',
#  'Mmas21',
#  'Mohammadreza.Esmaeili1',
#  'Molinaaraniva',
#  'Mornlas24',
#  'Mrbatman1990',
#  'Mubury',
#  'Muhre',
#  'Mwmaury',
#  'Mxolisi Ncube',
#  'Narjesjamm',
#  'NipMister96',
#  'Ob9u',
#  'Ovsgdl',
#  'Paatisekpolityka',
#  'Panisexualka',
#  'Paola Maria Chiesa',
#  'Paolo Tambú',
#  'Peggytoofire',
#  'Pelinsu89',
#  'Per Lykkelig',
#  'Pgoering',
#  'Poleo Cintia',
#  'Prehistony',
#  'PrimeBot2',
#  'Quintoxey',
#  'Rafaela Faria1',
#  'Rafsan78Bot',
#  'Raindooo',
#  'Randjela',
#  'Rapsemanal',
#  'Rhytaza',
#  'Robot595959',
#  'Rohr(Bergmann No.3)',
#  'Rubutic bot',
#  'SamiTK-T2',
#  'SanitaBB',
#  'Sargsyan Amalya',
#  'Sbot675',
#  'ScSiian',
#  'Solo1828',
#  'Stmediers',
#  'Swsbot',
#  'Syawalism',
#  'Sêmsurlu',
#  'Tanvir Ahmad Utsho',
#  'TeddyBot',
#  'Tehrancemusic',
#  'Thomas.F.A.D',
#  'Threehundredsongs',
#  'Tom Alexander Azevedo',
#  'Toxicpain',
#  'Tq93sgd5',
#  'Ttcath',
#  'Unipooh',
#  'UništihEkonomiju',
#  'Uthman Affan',
#  'Valerii Kolpakov',
#  'Vidyavachaspati Vidyanand',
#  'Washingtonsou4',
#  'WikiHuBot',
#  'Wssbot',
#  'XPosBot',
#  'Xinyue Huang DG2CI',
#  'Yyahmedsakr',
#  'Олександр Патейчук',
#  'אבנר כהן',
#  'איציק רוזן',
#  'آرش حسینی بازیگر',
#  'سمانه حامدی',
#  'தென்னை மருத்துவர்'}

# %%
result2 = wmf.spark.run("""
WITH editor_content_edits AS (
  SELECT 
    user_fingerprint_or_name AS user_name, 
    SUM(namespace_zero_edit_count) AS total_edit_count
  FROM 
    wmf.editors_daily
  WHERE 
    month = '2024-01'
    AND user_is_anonymous = FALSE
    AND size(user_is_bot_by) = 0
    AND action_type IN (0, 1)
  GROUP BY 
    user_fingerprint_or_name
), user_registration_dates AS (
  SELECT 
    event_user_text AS user_name, 
    MIN(event_user_creation_timestamp) AS min_registration_date
  FROM 
    wmf.mediawiki_history
  WHERE 
    snapshot = '2024-01'
    AND event_entity = 'user'
  GROUP BY 
    event_user_text
), editors_with_registration AS (
  SELECT 
    ece.user_name, 
    ece.total_edit_count, 
    urd.min_registration_date
  FROM 
    editor_content_edits ece
  JOIN 
    user_registration_dates urd 
  ON 
    ece.user_name = urd.user_name
), editors_with_country AS (
  SELECT 
    ewr.user_name, 
    ewr.total_edit_count, 
    ewr.min_registration_date, 
    ed.country_code
  FROM 
    editors_with_registration ewr
  JOIN 
    (SELECT DISTINCT user_fingerprint_or_name, country_code FROM wmf.editors_daily WHERE month = '2024-01') ed
  ON 
    ewr.user_name = ed.user_fingerprint_or_name
)
SELECT 
  *
FROM 
  editors_with_country
WHERE 
  total_edit_count >= 5
  and min_registration_date > '2023-12'


""")

result2
# Out:
#                    user_name  total_edit_count  min_registration_date  \
# 0                     666Pak                 5  2024-01-13 14:27:18.0
# 1      Abdul Rashid Seikh lp                23  2024-01-01 10:47:06.0
# 2      Abdul Rashid Seikh lp                23  2024-01-01 10:47:06.0
# 3      Abdul Rashid Seikh lp                23  2024-01-01 10:47:06.0
# 4                  Adamfragz                18  2023-12-30 10:56:34.0
# ...                      ...               ...                    ...
# 17251           Thinkonomics                 7  2024-01-25 00:54:08.0
# 17252           Unknown23467                 5  2024-01-14 02:09:18.0
# 17253             Xoxoxoxoko                64  2023-12-16 20:32:50.0
# 17254        XxItssDanielaxX                17  2024-01-03 12:29:46.0
# 17255                 भाजुधन                26  2024-01-17 05:06:35.0
#
#       country_code
# 0               FR
# 1               NL
# 2               DE
# 3               BR
# 4               GB
# ...            ...
# 17251           US
# 17252           AU
# 17253           IN
# 17254           ES
# 17255           US
#
# [17256 rows x 4 columns]

# %%
len(result2.user_name.unique())
# Out:
# 16174

# %%
result2['min_registration_date'] = pd.to_datetime(result2['min_registration_date'])
filtered_result = result2[result2['min_registration_date'] > '2023-12']

# %%
filtered_result
# Out:
#                    user_name  total_edit_count    month min_registration_date
# 1                     666Pak                 5  2024-01   2024-01-13 14:27:18
# 5      Abdul Rashid Seikh lp                23  2024-01   2024-01-01 10:47:06
# 6                  Adamfragz                18  2024-01   2023-12-30 10:56:34
# 11            Alina Sulowska                31  2024-01   2024-01-01 01:18:38
# 17                     Apocj                21  2024-01   2024-01-22 08:11:50
# ...                      ...               ...      ...                   ...
# 83997           Thinkonomics                 7  2024-01   2024-01-25 00:54:08
# 84010           Unknown23467                 5  2024-01   2024-01-14 02:09:18
# 84024             Xoxoxoxoko                64  2024-01   2023-12-16 20:32:50
# 84025        XxItssDanielaxX                17  2024-01   2024-01-03 12:29:46
# 84036                 भाजुधन                26  2024-01   2024-01-17 05:06:35
#
# [16174 rows x 4 columns]

# %%
len(filtered_result.user_name.unique())
# Out:
# 16174

# %%
query = wmf.spark.run("""
select month, country_code, namespace_zero_distinct_editors,  activity_level  from wmf.unique_editors_by_country_monthly
where month = '2024-01'
and activity_level != '1 to 4'
and users_are_anonymous = FALSE

""")

query
# Out:
#      month country_code  namespace_zero_distinct_editors activity_level
# 0  2024-01           US                             2058    100 or more
# 1  2024-01           US                            11309        5 to 99

# %%
query.namespace_zero_distinct_editors.sum()
# Out:
# 13367

# %%
df
# Out:
#                    user_name      registration_date  content_edits
# 0                     666Pak  2024-01-13 14:27:17.0              5
# 1      Abdul Rashid Seikh lp  2024-01-01 10:47:06.0             24
# 2             Alina Sulowska  2024-01-01 01:18:37.0             31
# 3                      Apocj  2024-01-22 08:11:49.0             68
# 4                    AsjaMas  2024-01-09 17:33:20.0              6
# ...                      ...                    ...            ...
# 15483           Unknown23467  2024-01-14 02:09:17.0              5
# 15484             User34264n  2024-01-10 10:57:16.0              6
# 15485        XxItssDanielaxX  2024-01-03 12:29:46.0             17
# 15486               کاراندیش  2024-01-09 16:44:25.0              8
# 15487                 भाजुधन  2024-01-17 05:06:34.0             26
#
# [15488 rows x 3 columns]

# %%
fixed[fixed['user_name'] == 'Adexgifted']
# Out:
#        month   user_name  content_edits  bot_by_group registration_month
# 0 2024-01-01  Adexgifted              6         False         2024-01-01

# %%
df[df['user_name'] == 'Adexgifted']
# Out:
# Empty DataFrame
# Columns: [user_name, registration_date, content_edits]
# Index: []
